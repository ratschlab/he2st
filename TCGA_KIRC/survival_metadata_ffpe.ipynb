# %%
import pandas as pd
import numpy as np
import glob
import yaml
import os
import xml.etree.ElementTree as ET

# %%
slide_type = "ffpe"
tcga_dataset = os.getcwd().split("/")[-1].lower().split("_")[1]
tcga_dataset, slide_type

# %%
with open(f"config_dataset_{slide_type}.yaml", "r") as stream:
    config_dataset = yaml.safe_load(stream)

metadata_path = config_dataset['metadata_path']
metadata_path

# %%
metadata = pd.read_csv(metadata_path)
metadata

# %%
survival_metadata = pd.read_excel("../ressources/1-s2.0-S0092867418302290-mmc1.xlsx", sheet_name=0)
survival_metadata = survival_metadata.rename({"bcr_patient_barcode": "case_id", 
                                              "type": "tcga_dataset", 
                                              "OS": "status", 
                                              "OS.time": "event_time",
                                              "age_at_initial_pathologic_diagnosis": "age"}, axis=1)
survival_metadata = survival_metadata[["case_id", "tcga_dataset", "status", "event_time", "age", "gender"]]
survival_metadata = survival_metadata.query(f"tcga_dataset == '{tcga_dataset.upper()}'")
survival_metadata.status = survival_metadata.status.apply(lambda x: "DEAD" if x else "ALIVE")
survival_metadata

# %%
survival_metadata = survival_metadata.drop_duplicates('case_id')
survival_metadata = survival_metadata[~survival_metadata.event_time.isna()]
survival_metadata = survival_metadata[~survival_metadata.age.isna()]
survival_metadata

# %%
survival_metadata.sort_values("case_id")

# %%
survival_metadata.status.value_counts()

# %%
survival_metadata.to_csv(f'{metadata_path.replace(".csv", "")}_survival.csv', index=False)
