# %%
import pandas as pd
import numpy as np
import plotnine as p9
import glob
import yaml
from plotnine_prism import *

# %%
with open("../config.yaml", "r") as stream:
    DATASET_INFO = yaml.safe_load(stream)
DATASET_INFO
# Out:
# {'DATASET_NAME': {'10x_TuPro': 'Tumor Profiler (n=18)',
#   'SCCRCC': 'Kidney cancer (n=24)',
#   'LUNG_CANCER': 'Lung cancer (n=36)',
#   'COAD': 'Colon cancer (HEST1K) (n=8)',
#   'USZ': 'Kidney/Lung with TLS (n=6)',
#   'Lung_Xenium': 'Lung cancer (10x Xenium) (n=17)',
#   'TCGA_SKCM_ffpe': 'TCGA SKCM (FFPE)',
#   'TCGA_SKCM_ff': 'TCGA SKCM (FF)',
#   'TCGA_KIRC_ffpe': 'TCGA KIRC (FFPE)',
#   'TCGA_KIRC_ff': 'TCGA KIRC (FF)',
#   'TCGA_LUAD_ffpe': 'TCGA LUAD (FFPE)',
#   'TCGA_LUAD_ff': 'TCGA LUAD (FF)',
#   'TCGA_LUSC_ffpe': 'TCGA LUSC (FFPE)',
#   'TCGA_LUSC_ff': 'TCGA LUSC (FF)'}}

# %%
pearson_variation_paths = glob.glob("../*/out_benchmark/evaluation/pearson_variation.csv")
pearson_variation_paths
# Out:
# ['../10x_TuPro/out_benchmark/evaluation/pearson_variation.csv',
#  '../cell_size_Lung_Xenium/out_benchmark/evaluation/pearson_variation.csv',
#  '../USZ/out_benchmark/evaluation/pearson_variation.csv',
#  '../SCCRCC/out_benchmark/evaluation/pearson_variation.csv',
#  '../USZ_test/out_benchmark/evaluation/pearson_variation.csv',
#  '../LUNG_CANCER/out_benchmark/evaluation/pearson_variation.csv',
#  '../IDC/out_benchmark/evaluation/pearson_variation.csv',
#  '../Lung_Xenium/out_benchmark/evaluation/pearson_variation.csv',
#  '../COAD/out_benchmark/evaluation/pearson_variation.csv']

# %%
data_var = []
for file in pearson_variation_paths:
    tab = pd.read_csv(file)
    dataset = file.split("/")[1]
    if dataset not in DATASET_INFO["DATASET_NAME"]: continue
    tab["Dataset"] = DATASET_INFO["DATASET_NAME"][dataset]
    data_var.append(tab)
data_var = pd.concat(data_var)
data_var.Dataset = pd.Categorical(data_var.Dataset, DATASET_INFO["DATASET_NAME"].values())
data_var.pearson_median = data_var.pearson_median.astype(float)
data_var.pearson_std = data_var.pearson_std.astype(float)
data_var
# Out:
#     pearson_median  pearson_std      model  top_n             model_AUC  \
# 0         0.293203     0.012088      BLEEP    100    BLEEP: 703.93±2.55
# 1         0.283322     0.011910      BLEEP    150    BLEEP: 703.93±2.55
# 2         0.273096     0.009945      BLEEP    200    BLEEP: 703.93±2.55
# 3         0.268316     0.008080      BLEEP    250    BLEEP: 703.93±2.55
# 4         0.258453     0.009768      BLEEP    300    BLEEP: 703.93±2.55
# ..             ...          ...        ...    ...                   ...
# 83       -0.000016     0.001184  THItoGene    500  THItoGene: 1.38±0.47
# 84        0.000700     0.000749  THItoGene   1000  THItoGene: 1.38±0.47
# 85        0.000611     0.000511  THItoGene   2000  THItoGene: 1.38±0.47
# 86        0.000157     0.000445  THItoGene   3000  THItoGene: 1.38±0.47
# 87        0.000114     0.000307  THItoGene   5000  THItoGene: 1.38±0.47
#
#                         Dataset
# 0         Tumor Profiler (n=18)
# 1         Tumor Profiler (n=18)
# 2         Tumor Profiler (n=18)
# 3         Tumor Profiler (n=18)
# 4         Tumor Profiler (n=18)
# ..                          ...
# 83  Colon cancer (HEST1K) (n=8)
# 84  Colon cancer (HEST1K) (n=8)
# 85  Colon cancer (HEST1K) (n=8)
# 86  Colon cancer (HEST1K) (n=8)
# 87  Colon cancer (HEST1K) (n=8)
#
# [460 rows x 6 columns]

# %%
data_var.query("Dataset == 'Tumor Profiler (n=18)' and top_n in [500]").sort_values("pearson_median")
# Out:
#     pearson_median  pearson_std             model  top_n  \
# 83       -0.019731     0.001532         THItoGene    500
# 39        0.006280     0.000763           Hist2ST    500
# 28        0.028629     0.004386         HisToGene    500
# 6         0.232397     0.005841             BLEEP    500
# 50        0.235574     0.006262  LinearRegression    500
# 72        0.239007     0.006033             STNet    500
# 61        0.242075     0.004939               MLP    500
# 17        0.310125     0.005927          DeepSpot    500
#
#                         model_AUC                Dataset
# 83         THItoGene: -39.19±0.48  Tumor Profiler (n=18)
# 39            Hist2ST: 22.21±0.22  Tumor Profiler (n=18)
# 28          HisToGene: 67.00±1.07  Tumor Profiler (n=18)
# 6              BLEEP: 703.93±2.55  Tumor Profiler (n=18)
# 50  LinearRegression: 695.58±2.32  Tumor Profiler (n=18)
# 72             STNet: 620.80±2.79  Tumor Profiler (n=18)
# 61               MLP: 731.34±2.30  Tumor Profiler (n=18)
# 17          DeepSpot: 986.73±2.96  Tumor Profiler (n=18)

# %%
data_var.query("top_n in [3000]").sort_values("pearson_median")
# Out:
#     pearson_median  pearson_std             model  top_n  \
# 86       -0.004080     0.000443         THItoGene   3000
# 86       -0.000345     0.000262         THItoGene   3000
# 42       -0.000179     0.000346           Hist2ST   3000
# 42        0.000098     0.000169           Hist2ST   3000
# 86        0.000157     0.000445         THItoGene   3000
# 31        0.000266     0.000223         HisToGene   3000
# 42        0.000733     0.000418           Hist2ST   3000
# 31        0.001966     0.000123         HisToGene   3000
# 31        0.002227     0.000364         HisToGene   3000
# 86        0.003668     0.000224         THItoGene   3000
# 42        0.004302     0.000208           Hist2ST   3000
# 31        0.009329     0.000628         HisToGene   3000
# 64        0.010694     0.000400               MLP   3000
# 75        0.011160     0.000424             STNet   3000
# 75        0.011720     0.000514             STNet   3000
# 53        0.011836     0.000438  LinearRegression   3000
# 75        0.013215     0.000394             STNet   3000
# 53        0.014034     0.000637  LinearRegression   3000
# 42        0.016051     0.000312           Hist2ST   3000
# 31        0.017071     0.000513         HisToGene   3000
# 86        0.017217     0.000823         THItoGene   3000
# 9         0.018633     0.000324             BLEEP   3000
# 64        0.020473     0.000782               MLP   3000
# 9         0.021064     0.000566             BLEEP   3000
# 9         0.028482     0.000867             BLEEP   3000
# 53        0.031274     0.000602  LinearRegression   3000
# 64        0.033615     0.000585               MLP   3000
# 20        0.049153     0.001302          DeepSpot   3000
# 20        0.050464     0.000927          DeepSpot   3000
# 20        0.055537     0.001015          DeepSpot   3000
# 75        0.056690     0.001780             STNet   3000
# 53        0.073924     0.001648  LinearRegression   3000
# 9         0.077934     0.001435             BLEEP   3000
# 64        0.088370     0.001759               MLP   3000
# 75        0.097494     0.002287             STNet   3000
# 53        0.116856     0.001960  LinearRegression   3000
# 20        0.117326     0.001982          DeepSpot   3000
# 9         0.119750     0.002230             BLEEP   3000
# 64        0.123363     0.002165               MLP   3000
# 20        0.172924     0.002746          DeepSpot   3000
#
#                         model_AUC                      Dataset
# 86         THItoGene: -39.19±0.48        Tumor Profiler (n=18)
# 86           THItoGene: 0.37±0.28   Kidney/Lung with TLS (n=6)
# 42            Hist2ST: -2.10±0.38   Kidney/Lung with TLS (n=6)
# 42            Hist2ST: -1.79±0.20         Kidney cancer (n=24)
# 86           THItoGene: 1.38±0.47  Colon cancer (HEST1K) (n=8)
# 31           HisToGene: 2.49±0.27   Kidney/Lung with TLS (n=6)
# 42             Hist2ST: 4.86±0.46  Colon cancer (HEST1K) (n=8)
# 31          HisToGene: 11.98±0.17         Kidney cancer (n=24)
# 31          HisToGene: 24.89±0.52  Colon cancer (HEST1K) (n=8)
# 86          THItoGene: 19.59±0.24         Kidney cancer (n=24)
# 42            Hist2ST: 22.21±0.22        Tumor Profiler (n=18)
# 31          HisToGene: 67.00±1.07        Tumor Profiler (n=18)
# 64                MLP: 74.99±0.45   Kidney/Lung with TLS (n=6)
# 75              STNet: 74.12±0.44   Kidney/Lung with TLS (n=6)
# 75             STNet: 109.66±0.73  Colon cancer (HEST1K) (n=8)
# 53   LinearRegression: 77.76±0.47   Kidney/Lung with TLS (n=6)
# 75              STNet: 81.82±0.49         Kidney cancer (n=24)
# 53  LinearRegression: 118.01±0.84  Colon cancer (HEST1K) (n=8)
# 42            Hist2ST: 89.74±0.38           Lung cancer (n=36)
# 31          HisToGene: 92.70±0.69           Lung cancer (n=36)
# 86          THItoGene: 95.15±0.96           Lung cancer (n=36)
# 9              BLEEP: 106.97±0.39         Kidney cancer (n=24)
# 64               MLP: 161.19±0.96  Colon cancer (HEST1K) (n=8)
# 9              BLEEP: 121.46±0.68   Kidney/Lung with TLS (n=6)
# 9              BLEEP: 202.53±1.07  Colon cancer (HEST1K) (n=8)
# 53  LinearRegression: 187.84±0.71         Kidney cancer (n=24)
# 64               MLP: 195.55±0.71         Kidney cancer (n=24)
# 20          DeepSpot: 346.46±1.51  Colon cancer (HEST1K) (n=8)
# 20          DeepSpot: 284.89±1.18   Kidney/Lung with TLS (n=6)
# 20          DeepSpot: 315.04±1.11         Kidney cancer (n=24)
# 75             STNet: 339.66±2.09           Lung cancer (n=36)
# 53  LinearRegression: 428.75±1.98           Lung cancer (n=36)
# 9              BLEEP: 433.59±1.76           Lung cancer (n=36)
# 64               MLP: 485.83±1.81           Lung cancer (n=36)
# 75             STNet: 620.80±2.79        Tumor Profiler (n=18)
# 53  LinearRegression: 695.58±2.32        Tumor Profiler (n=18)
# 20          DeepSpot: 629.02±2.32           Lung cancer (n=36)
# 9              BLEEP: 703.93±2.55        Tumor Profiler (n=18)
# 64               MLP: 731.34±2.30        Tumor Profiler (n=18)
# 20          DeepSpot: 986.73±2.96        Tumor Profiler (n=18)

# %%
tab = data_var.copy()
position_dodge_width = 0.5
tab = tab.query("Dataset in ['Lung cancer (n=36)']")
tab["model_rank"] = tab.groupby("Dataset", observed=False).pearson_median.rank(ascending=False)
tab["Model"] = pd.Categorical(tab.model, tab.groupby("model").model_rank.agg("median").sort_values().index)
tab.top_n = tab.top_n.astype("category")

g = (p9.ggplot(tab, p9.aes("top_n", "pearson_median", color="Model"))
 + p9.geom_line(p9.aes(color="Model", group="Model"), linetype="dashed", 
                position=p9.position_dodge(width=position_dodge_width))
 + p9.geom_point(p9.aes(color="Model"), position=p9.position_dodge(width=position_dodge_width), size=0.7) 
 + p9.facet_wrap("~Dataset", scales="free_y", ncol=2)
 + p9.geom_errorbar(p9.aes(x="top_n", ymin="pearson_median-pearson_std",
                           ymax="pearson_median+pearson_std", color="Model"), 
                    width=0.4, alpha=1, size=0.5,
                    position=p9.position_dodge(width=position_dodge_width))
 + p9.theme_bw()
 + p9.theme(panel_spacing_y=0, panel_spacing_x=0, figure_size=(8, 4), 
            #axis_text_x = p9.element_blank(), 
            legend_position="right",
            text=p9.element_text(size=17),
            strip_text=p9.element_text(size=17),
            legend_title=p9.element_text(size=17),
            legend_text=p9.element_text(size=16))
 + p9.ylab("Pearson correlation")
 + p9.xlab("Most variable genes")
 + p9.theme(axis_text_x = p9.element_text(angle = 90, hjust = 1))
 + scale_color_prism(palette = "colors")
 + p9.guides(color=p9.guide_legend(nrow=10, override_aes = p9.aes(shape = ".")))
)
g.save("figures/FigureS2-lung_cancer.png", dpi=300)
g
# Out:
# /cluster/customapps/biomed/grlab/users/knonchev/miniconda3/envs/nonchev/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 8 x 4 in image.
# /cluster/customapps/biomed/grlab/users/knonchev/miniconda3/envs/nonchev/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: figures/FigureS2-lung_cancer.png
# <Figure Size: (800 x 400)>
